# %%
# Slicing - access multiple elements at a time
s = 'This is Python class'
# Syntax - square bracket notation - s[start:stop:step]
# Default value of step is 1
# Default start - 0
# default stop - len(str)

# Default value of step is -1 (-ve) then start and stop gets swapped

# In slicing start, stop and step everything is optional

# Step -> +ve value then slicing will be done from Left to Right
# Step -> -ve value then slicing will be done from Right to Left

# ---------------------->  step +ve
# 'This is Python class'
# <----------------------  step -ve

# Step value can be any whole number - (1/-1 -> Every character),(2,-2 -> Every second character),(3,-3 -> Every third character) and so on

# len() - function works on the string and mapping to give the number of elements in the object



# print('Slicing the whole string => ',s[::])
# print('Slicing the whole string => ',s[0:len(s):1])
# print('Slicing Python from s => ',s[8:14:1])
# print('Slicing Python from s => ',s[8:14])
# print('Slicing Python from s => ',s[0:1000])
# print('Slicing the string in reverse order =>', s[::-1])
# print('Slicing the string in reverse order =>', s[len(s)-1::-1])
# print('Slicing the string in reverse order =>', s[-1:-len(s)-1:-1])

# print('Slicing the whole string => ',s[::2])
# print('Slicing the whole string => ',s[::-2])
# print(s[::5])

s = 'This is Python class'
# print(s[-5::1])
# print(s[::])

# print(s[s.index('is', 5)::])
# print(s[::30])
# print(s[8:14:])

# Basic operation on Strings - concatenation(Combining two strings), Repetition(Repeting one strinhg multiple times), membership(To check whetehr a charcter or group of characters are available in the seq - in & not in), identity(it just check the object are sharing the same id or not -> is & is not)

# Concatenation of string - both the operands should be of string type, returns a modified string object, concatenation is not going to make any changes to the original strings
s1 = ' at Learnbay.'
# print(s+s1)
# print(s+10)
# print(s+str(10))
# print(s+[10,20,30])

# print(s, id(s))
# print(s1,id(s1))
# print(s+s1, id(s+s1))


# Repetition - One operand should be string and the other should be integer, returns a modified string object, repetition is not going to make any changes to the original strings
print(s*2)
# print(s*s1)

# Membership - always returns Boolean value
# print('T' in s)
# print('This' in s)
# print('this' in s)
# print('P' in s, 'n' in s)
# print('n' in s)
# print('Python' in s)
# print('s' in s[8:14])
print(s.count('s'))

# t = 'this is python class'
# print (t[-1:-6:-1][::-1])
# print('p' and 'n' and 's' in S)

# print(10,20)

# print('p' and 'n' and 's')
# Out:
# This is Python classThis is Python class
# 4

# %%
# Derived Data types in Python - List, tuple, set, frozenset, dictionary, bytes, bytearray, range

# %% [markdown]
# # List

# %%
# List a seq
    # List is an ordered collection of elements
    # It supports +ve and -ve indexing both
    # It supports Slicing
    # List can have duplicate elements
    # List is a collection of heterogeneous lements
    # List is mutable
# While defining a list elements should be kept inside the square bracket sepoarated by comma, square bracket is manadtory

lst = [10, 10.20, 10+20j, 'Python', None, True, [1,2,3], (10,20,30), {100,200,300}, {1:100, 2:200, 3:300}, 10, 10.20, 10+20j]
print(lst, type(lst))

# Array - is a homogeneous collection of data - supports - int, float, complex, object
import numpy as np
arr1 = np.array(lst)
print(arr1,arr1.dtype)

arr2 = np.array([10,20,30,40, 50.40])
print(arr2, arr2.dtype)

# # int -> float -> complex -> object



# short type - 0 to 256, -128 to 127
# int type - 0 to 2^16


# lst1 = lst[]
# print(lst)
# print(lst1)
# Out:
# [10, 10.2, (10+20j), 'Python', None, True, [1, 2, 3], (10, 20, 30), {200, 100, 300}, {1: 100, 2: 200, 3: 300}, 10, 10.2, (10+20j)] <class 'list'>
# [10 10.2 (10+20j) 'Python' None True list([1, 2, 3]) (10, 20, 30)
#  {200, 100, 300} {1: 100, 2: 200, 3: 300} 10 10.2 (10+20j)] object
# [10.  20.  30.  40.  50.4] float64

# %%
# Object Reusability - You can reuse the objects in python, Python supports interning (caching values or data)
# is followed by
#     int - -5 to 256
#     string - A to Z and a to z and 0 to 9
#     None
#     Boolean - True and False

# Not followed by
#     Float and complex and also by derived data type

# a = 10
# b = 10
# c = 15
# print(id(a))
# print(id(b))
# print(id(c))

# a = 260
# b = 260
# print(id(a))
# print(id(b))


# For string it follows
# a = 'Python'
# b = 'Python'
# print(id(a))
# print(id(b))
# print(a is b)

a = 'Python#'
b = 'Python#'
# print(id(a))
# print(id(b))
# print(a is b)
# print(a[0] is b[0])
# print(a[-1] is b[-1])


# Why only in this range?, Not following for the float?

# a = 10.6
# b = 10.6
# print(id(a))
# print(id(b))


# Interning - 0 and 1 - infinite

# a = 'Python16'
# b = 'Python13'
# print(a[-2] is b[-2])
# print(a[-1] is b[-1])


a = 'python'
meatPrice = 4.00
meatTax = 0.03 * meatPrice
print(4.00*0.03)
milkPrice = 2.00
milkTax = 0.03 * milkPrice
print(2.00*0.03)
print(meatTax + meatPrice + milkTax + milkPrice)
# Out:
# 0.12
# 0.06
# 6.18
